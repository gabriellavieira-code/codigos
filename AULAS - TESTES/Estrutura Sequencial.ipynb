# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print("Alo mundo")
# Out:
# Alo mundo

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
numero=input("me informe um numero:")
print(f"O número informado foi {numero}")
# Out:
# O número informado foi 8

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
numero1 =input("me informe 1 numero:")
numero2 =input("me informe 1 numero:")

soma = int(numero1) + int(numero2)

print(f"A soma dos números é {soma}")
# Out:
# A soma dos números é 67

# %%
numero1 = int(input("me informe 1 numero: "))
numero2 = int(input("me informe 1 numero: "))

soma = numero1 + numero2

print(f"A soma dos números é {soma}")
# Out:
# A soma dos números é 67

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %% [markdown]
# O que o problema está pedindo (traduzido)
#
# “Peça 4 notas bimestrais de um aluno e mostre a média.”
#
# Em termos simples:
# Preciso coletar 4 valores
# Esses valores representam números
# Depois preciso fazer uma conta
# E por fim mostrar o resultado
#
# Que operações existem aqui?
# Só duas:
# Entrada de dados → input
# Cálculo matemático → soma e divisão
#
# Raciocínio passo a passo (sem Python ainda)
# Perguntar as notas
#
# Você vai perguntar:
# nota 1
# nota 2
# nota 3
# nota 4
# Cada pergunta gera um valor separado.
#
# Entender o tipo dessas notas
#
# Regra que você já aprendeu:
# input() sempre retorna texto
#
# Mas nota é número, então:
# Se você quiser somar
# Precisa transformar em número
# Aqui entra int ou float.
#
# Nota normalmente aceita decimal, então já fica o alerta:
# float faz mais sentido do que int
#
# Guardar cada nota
#
# Cada nota precisa ficar:
# em uma variável
# para ser usada depois
#
# Exemplo mental (não código):
# nota1
# nota2
# nota3
# nota4
#
# Calcular a média
# A fórmula da média é sempre:
# média = soma dos valores ÷ quantidade de valores
#
# Nesse caso:
# Soma das 4 notas
# Divide por 4
#
# Mostrar o resultado
#
# Por fim:
# Você exibe uma mensagem
# Misturando texto + valor calculado
# Aqui o f"" entra naturalmente
#
# Checklist mental (guarda isso)
#
# Antes de escrever qualquer linha de código, você consegue responder:
# Quantos input? → 4
# Precisa converter tipo? → Sim
# Qual operação matemática? → soma + divisão
# O que mostrar no final? → a média

# %%
nota1 = float(input("Informe a primeira nota: "))
nota2 = float(input("Informe a segunda nota: "))
nota3 = float(input("Informe a terceira nota: "))
nota4 = float(input("Informe a quarta nota: "))

media = (nota1 + nota2 + nota3 + nota4) / 4

print(f"A média de todas as notas é {media:.2f}")
# Out:
# A média de todas as notas é 8.00

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
centimetros = float(input("Informe o valor em centimetros: "))

metros = centimetros / 100

print(f"O valor em metros é {metros} m")
# Out:
# O valor em metros é 2.9995 m

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
Lsala = float(input("Informe a largura da sala em metros: "))
Csala = float(input("Informe o comprimento da sala em metros: "))

Áreasala = Lsala * Csala

print(f"A área da sala é {Áreasala} m²")
# Out:
# A área da sala é 40.0 m²

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
salario_hora = float(input("Informe o valor do salário por hora: "))
horas_trabalhadas = float(input("Informe o número de horas trabalhadas no mês: "))

salario_mensal = salario_hora * horas_trabalhadas

print(f"O salário mensal é R$ {salario_mensal:.2f}")
# Out:
# O salário mensal é R$ 8400.00

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
temperatura_fahrenheit = float(input("Informe a temperatura em Fahrenheit: "))
temperatura_celsius = (5/9) * (temperatura_fahrenheit - 32)

print(f"A temperatura em Celsius é {temperatura_celsius:.2f} °C")
# Out:
# A temperatura em Celsius é 20.00 °C

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
temperatura_celsius = float(input("Informe a temperatura em Celsius: "))
temperatura_fahrenheit = (9/5) * temperatura_celsius + 32

print(f"A temperatura em Fahrenheit é {temperatura_fahrenheit:.2f} °F")
# Out:
# A temperatura em Fahrenheit é 122.00 °F

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura = 1.58

peso_ideal = (72.7 * altura) - 58
print(f"O peso ideal para uma pessoa com altura {altura}m é {peso_ideal:.2f}kg")
# Out:
# O peso ideal para uma pessoa com altura 1.58m é 56.87kg

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
Altura = 1.58

peso_ideal_homem = (72.7 * Altura) - 58
print(f"O peso ideal para um homem com altura {Altura}m é {peso_ideal_homem:.2f}kg")
                                                             
peso_ideal_mulher = (62.1 * Altura) - 44.7
print(f"O peso ideal para uma mulher com altura {Altura}m é {peso_ideal_mulher:.2f}kg")
# Out:
# O peso ideal para um homem com altura 1.58m é 56.87kg
# O peso ideal para uma mulher com altura 1.58m é 53.42kg

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
ganha_por_hora = float(input("Informe quanto você ganha por hora: "))
horas_trabalhadas_no_mes = float(input("Informe quantas horas você trabalha no mês: "))

print(f"Seu salário mensal é R$ {ganha_por_hora * horas_trabalhadas_no_mes:.2f}")
# Out:
# Seu salário mensal é R$ 8000.00

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
horas_trabalhadas_no_mes = 160
salario_por_hora = 50.0

print(f"Seu salário mensal é R$ {salario_por_hora * horas_trabalhadas_no_mes:.2f}")
# Out:
# Seu salário mensal é R$ 8000.00

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
salario_mensal = 8000
imposto_de_renda = salario_mensal * 0.11

print(f"O valor do imposto de renda é R$ {imposto_de_renda:.2f}")
# Out:
# O valor do imposto de renda é R$ 880.00

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
salario_mensal = 8000
INSS = salario_mensal * 0.08

print(f"O valor do INSS é R$ {INSS:.2f}")
# Out:
# O valor do INSS é R$ 640.00

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
salario_mensal = 8000   
sindicato = salario_mensal * 0.05

print(f"O valor do sindicato é R$ {sindicato:.2f}")
# Out:
# O valor do sindicato é R$ 400.00

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
salario_mensal = 8000
imposto_de_renda = 880
INSS = 640
sindicato = 400

salarioliquido = salario_mensal - (imposto_de_renda + INSS + sindicato)

print(f"O salário líquido é R$ {salarioliquido:.2f}")
# Out:
# O salário líquido é R$ 6080.00

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
area = float(input("Informe a área em m² a ser pintada: "))

litros_necessarios = area / 3
latas = litros_necessarios / 18
preco_total = latas * 80

print(f"Você precisará de {latas:.2f} latas de tinta, totalizando R$ {preco_total:.2f}")
# Out:
# Você precisará de 1.00 latas de tinta, totalizando R$ 80.00

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
tamanho = float(input('Informe o tamanho do arquivo em MB: '))
velocidade = float(input('Informe a velocidade da conexão em Mbps: '))

# aqui trasnformamos megabytes em megabits para que tamanho e velocidade estejam na mesma unidade
tamanho_megabits = tamanho * 8

tempo = tamanho_megabits / velocidade
# transformando em minutos
tempo_minutos = tempo / 60
print(f'O tempo de download é de {tempo_minutos} minutos')
# Out:
# O tempo de download é de 0.8 minutos
