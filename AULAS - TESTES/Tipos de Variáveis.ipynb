# %% [markdown]
# # Tipos de Variáveis em Python

# %% [markdown]
# Uma variável é um objeto, afinal tudo é um objeto em Python
#
# int -> inteiro<br>
# string -> texto<br>
# float -> números com casas decimais (ponto flutuante)<br>
# bool ou boolean -> True ou False<br>
#
# Obs: Variáveis em Python não são declaradas explicitamente, mas isso não significa que você deve ficar mudando o tempo todo
#
# Obs2: Cuidado com os nomes restritos (arquivo para Download)

# %%
## TREINANDO COM FATURAMENTO, CUSTO E LUCRO _____
faturamento = 5000
custo = 500
lucro = faturamento - custo

print("o faturamento da loja foi" + str(faturamento))
print("o custo da loja foi" + str(custo))
print("Assim, o lucro da loja foi de" + str(lucro) + "reais")

## TREINANDO COM CIDADE E ESTADO _____
cidade = "Vitória"
estado = "ES"

endereco = cidade + " - " + estado
print(endereco)
print("O endereço completo é: " + endereco)

# TREINANDO COM IDADE _____
idade = 30
print("Idade: " + str(idade))
# Out:
# o faturamento da loja foi5000
# o custo da loja foi500
# Assim, o lucro da loja foi de4500reais
# Vitória - ES
# O endereço completo é: Vitória - ES
# Idade: 30

# %%
faturamento = 1000
type(faturamento)
# Out:
# int

# %%
faturamento = 1000.00
type(faturamento)
# Out:
# float

# %%
faturamento = '1.000'
type(faturamento)
# Out:
# str

# %%
ganha_bonus = True
type(ganha_bonus)
# Out:
# bool
